# %%
import pandas as pd
import requests
import time
import os

# %%
df = pd.read_csv('foxnews-transcript-urls-2025.csv.gz')
df
# Out:
#                                                 imageUrl  \
# 0      https://a57.foxnews.com/cf-images.us-east-1.pr...
# 1      https://a57.foxnews.com/cf-images.us-east-1.pr...
# 2      https://a57.foxnews.com/cf-images.us-east-1.pr...
# 3      https://a57.foxnews.com/cf-images.us-east-1.pr...
# 4      https://a57.foxnews.com/cf-images.us-east-1.pr...
# ...                                                  ...
# 54377  https://a57.foxnews.com/cf-images.us-east-1.pr...
# 54378  https://a57.foxnews.com/cf-images.us-east-1.pr...
# 54379  https://a57.foxnews.com/static.foxnews.com/fox...
# 54380  https://a57.foxnews.com/cf-images.us-east-1.pr...
# 54381  https://a57.foxnews.com/cf-images.us-east-1.pr...
#
#                                                    title  \
# 0                  'Fox News Sunday' on October 20, 2024
# 1                'Fox News Sunday' on September 15, 2024
# 2                 'Fox News Sunday' on September 8, 2024
# 3                   'Fox News Sunday' on August 25, 2024
# 4                     'Fox News Sunday' on July 21, 2024
# ...                                                  ...
# 54377  Chicago mother describes struggles of remote l...
# 54378  How polls are reacting to Trump, Biden campaig...
# 54379  Martha MacCallum presses teachers' union head ...
# 54380  Pete Buttigieg slams Trump for taking credit f...
# 54381  How American foreign policy has changed under ...
#
#                                              description  \
# 0      Maryland Gov. Wes Moore weighs in on Harris' p...
# 1      ‘Fox News Sunday’ anchor Shannon Bream welcome...
# 2      This week on 'Fox News Sunday,' host Shannon B...
# 3      This week on ‘Fox News Sunday,’ host Shannon B...
# 4      This week on ‘Fox News Sunday,’ Shannon Bream ...
# ...                                                  ...
# 54377                                                NaN
# 54378                                                NaN
# 54379  "The Story" host Martha MacCallum tangled with...
# 54380                                                NaN
# 54381                                                NaN
#
#                                                      url  \
# 0            /transcript/fox-news-sunday-october-20-2024
# 1          /transcript/fox-news-sunday-september-15-2024
# 2           /transcript/fox-news-sunday-september-8-2024
# 3                  /media/fox-news-sunday-august-25-2024
# 4               /transcript/fox-news-sunday-july-21-2024
# ...                                                  ...
# 54377  /transcript/chicago-mother-describes-struggles...
# 54378  /transcript/how-polls-are-reacting-to-trump-bi...
# 54379  /media/martha-maccallum-randi-weingarten-nyc-s...
# 54380  /transcript/pete-buttigieg-slams-trump-for-tak...
# 54381  /transcript/how-american-foreign-policy-has-ch...
#
#                  publicationDate          lastPublishedDate  \
# 0      2024-10-27 18:14:43+00:00  2024-10-27T14:14:43-04:00
# 1      2024-10-07 13:01:55+00:00  2024-10-07T09:01:55-04:00
# 2      2024-09-10 22:04:22+00:00  2024-09-10T18:04:22-04:00
# 3      2024-08-25 17:40:15+00:00  2024-08-25T13:40:15-04:00
# 4      2024-07-21 17:53:48+00:00  2024-07-21T13:53:48-04:00
# ...                          ...                        ...
# 54377  2021-01-29 15:21:40+00:00  2021-01-29T10:21:40-05:00
# 54378  2020-09-24 16:53:37+00:00  2020-11-25T12:54:46-05:00
# 54379  2020-11-20 01:58:37+00:00  2020-11-19T20:58:37-05:00
# 54380  2020-11-02 15:10:00+00:00  2020-11-14T10:11:20-05:00
# 54381  2020-11-14 14:23:25+00:00  2020-11-14T09:23:25-05:00
#
#                                                 category  isBreaking isLive  \
# 0      {'name': 'TRANSCRIPT', 'url': '/category/shows...       False  False
# 1      {'name': 'TRANSCRIPT', 'url': '/category/shows...       False  False
# 2      {'name': 'TRANSCRIPT', 'url': '/category/shows...       False  False
# 3      {'name': 'TRANSCRIPT', 'url': '/category/shows...       False  False
# 4      {'name': 'TRANSCRIPT', 'url': '/category/shows...       False  False
# ...                                                  ...         ...    ...
# 54377  {'name': 'The Story with Martha MacCallum Tran...       False  False
# 54378  {'name': 'The Story with Martha MacCallum Tran...       False  False
# 54379  {'name': 'Fox News Flash', 'url': '/category/m...       False  False
# 54380  {'name': 'The Story with Martha MacCallum Tran...       False  False
# 54381  {'name': 'The Story with Martha MacCallum Tran...       False  False
#
#       duration                           authors
# 0          NaN      [{'name': 'Fox News Staff'}]
# 1          NaN      [{'name': 'Fox News Staff'}]
# 2          NaN      [{'name': 'Fox News Staff'}]
# 3          NaN        [{'name': 'kayla bailey'}]
# 4          NaN      [{'name': 'Fox News Staff'}]
# ...        ...                               ...
# 54377      NaN                                []
# 54378      NaN                                []
# 54379      NaN  [{'name': 'Samuel Chamberlain'}]
# 54380      NaN                                []
# 54381      NaN                                []
#
# [54382 rows x 11 columns]

# %%
len(df.url.unique())
# Out:
# 54382

# %%
df['html_file'] = df.url.apply(lambda c: c.split('/')[-1] + '.html')
df
# Out:
#                                                 imageUrl  \
# 0      https://a57.foxnews.com/cf-images.us-east-1.pr...
# 1      https://a57.foxnews.com/cf-images.us-east-1.pr...
# 2      https://a57.foxnews.com/cf-images.us-east-1.pr...
# 3      https://a57.foxnews.com/cf-images.us-east-1.pr...
# 4      https://a57.foxnews.com/cf-images.us-east-1.pr...
# ...                                                  ...
# 54377  https://a57.foxnews.com/cf-images.us-east-1.pr...
# 54378  https://a57.foxnews.com/cf-images.us-east-1.pr...
# 54379  https://a57.foxnews.com/static.foxnews.com/fox...
# 54380  https://a57.foxnews.com/cf-images.us-east-1.pr...
# 54381  https://a57.foxnews.com/cf-images.us-east-1.pr...
#
#                                                    title  \
# 0                  'Fox News Sunday' on October 20, 2024
# 1                'Fox News Sunday' on September 15, 2024
# 2                 'Fox News Sunday' on September 8, 2024
# 3                   'Fox News Sunday' on August 25, 2024
# 4                     'Fox News Sunday' on July 21, 2024
# ...                                                  ...
# 54377  Chicago mother describes struggles of remote l...
# 54378  How polls are reacting to Trump, Biden campaig...
# 54379  Martha MacCallum presses teachers' union head ...
# 54380  Pete Buttigieg slams Trump for taking credit f...
# 54381  How American foreign policy has changed under ...
#
#                                              description  \
# 0      Maryland Gov. Wes Moore weighs in on Harris' p...
# 1      ‘Fox News Sunday’ anchor Shannon Bream welcome...
# 2      This week on 'Fox News Sunday,' host Shannon B...
# 3      This week on ‘Fox News Sunday,’ host Shannon B...
# 4      This week on ‘Fox News Sunday,’ Shannon Bream ...
# ...                                                  ...
# 54377                                                NaN
# 54378                                                NaN
# 54379  "The Story" host Martha MacCallum tangled with...
# 54380                                                NaN
# 54381                                                NaN
#
#                                                      url  \
# 0            /transcript/fox-news-sunday-october-20-2024
# 1          /transcript/fox-news-sunday-september-15-2024
# 2           /transcript/fox-news-sunday-september-8-2024
# 3                  /media/fox-news-sunday-august-25-2024
# 4               /transcript/fox-news-sunday-july-21-2024
# ...                                                  ...
# 54377  /transcript/chicago-mother-describes-struggles...
# 54378  /transcript/how-polls-are-reacting-to-trump-bi...
# 54379  /media/martha-maccallum-randi-weingarten-nyc-s...
# 54380  /transcript/pete-buttigieg-slams-trump-for-tak...
# 54381  /transcript/how-american-foreign-policy-has-ch...
#
#                  publicationDate          lastPublishedDate  \
# 0      2024-10-27 18:14:43+00:00  2024-10-27T14:14:43-04:00
# 1      2024-10-07 13:01:55+00:00  2024-10-07T09:01:55-04:00
# 2      2024-09-10 22:04:22+00:00  2024-09-10T18:04:22-04:00
# 3      2024-08-25 17:40:15+00:00  2024-08-25T13:40:15-04:00
# 4      2024-07-21 17:53:48+00:00  2024-07-21T13:53:48-04:00
# ...                          ...                        ...
# 54377  2021-01-29 15:21:40+00:00  2021-01-29T10:21:40-05:00
# 54378  2020-09-24 16:53:37+00:00  2020-11-25T12:54:46-05:00
# 54379  2020-11-20 01:58:37+00:00  2020-11-19T20:58:37-05:00
# 54380  2020-11-02 15:10:00+00:00  2020-11-14T10:11:20-05:00
# 54381  2020-11-14 14:23:25+00:00  2020-11-14T09:23:25-05:00
#
#                                                 category  isBreaking isLive  \
# 0      {'name': 'TRANSCRIPT', 'url': '/category/shows...       False  False
# 1      {'name': 'TRANSCRIPT', 'url': '/category/shows...       False  False
# 2      {'name': 'TRANSCRIPT', 'url': '/category/shows...       False  False
# 3      {'name': 'TRANSCRIPT', 'url': '/category/shows...       False  False
# 4      {'name': 'TRANSCRIPT', 'url': '/category/shows...       False  False
# ...                                                  ...         ...    ...
# 54377  {'name': 'The Story with Martha MacCallum Tran...       False  False
# 54378  {'name': 'The Story with Martha MacCallum Tran...       False  False
# 54379  {'name': 'Fox News Flash', 'url': '/category/m...       False  False
# 54380  {'name': 'The Story with Martha MacCallum Tran...       False  False
# 54381  {'name': 'The Story with Martha MacCallum Tran...       False  False
#
#       duration                           authors  \
# 0          NaN      [{'name': 'Fox News Staff'}]
# 1          NaN      [{'name': 'Fox News Staff'}]
# 2          NaN      [{'name': 'Fox News Staff'}]
# 3          NaN        [{'name': 'kayla bailey'}]
# 4          NaN      [{'name': 'Fox News Staff'}]
# ...        ...                               ...
# 54377      NaN                                []
# 54378      NaN                                []
# 54379      NaN  [{'name': 'Samuel Chamberlain'}]
# 54380      NaN                                []
# 54381      NaN                                []
#
#                                                html_file
# 0                   fox-news-sunday-october-20-2024.html
# 1                 fox-news-sunday-september-15-2024.html
# 2                  fox-news-sunday-september-8-2024.html
# 3                    fox-news-sunday-august-25-2024.html
# 4                      fox-news-sunday-july-21-2024.html
# ...                                                  ...
# 54377  chicago-mother-describes-struggles-of-remote-l...
# 54378  how-polls-are-reacting-to-trump-biden-campaign...
# 54379  martha-maccallum-randi-weingarten-nyc-school-c...
# 54380  pete-buttigieg-slams-trump-for-taking-credit-f...
# 54381  how-american-foreign-policy-has-changed-under-...
#
# [54382 rows x 12 columns]

# %%
df[df.duplicated(subset=['html_file'])]
# Out:
#                                                imageUrl  \
# 4536  https://a57.foxnews.com/static.foxnews.com/fox...
# 4548  https://a57.foxnews.com/cf-images.us-east-1.pr...
# 4692  https://a57.foxnews.com/static.foxnews.com/fox...
#
#                                                   title  \
# 4536  Tucker Carlson: The price of US gas now qualif...
# 4548  Tucker Carlson: Elizabeth Warren wants control...
# 4692  Tucker Carlson: Biden’s economic policy, labor...
#
#                                             description  \
# 4536  "Tucker Carlson Tonight" host calls out Presid...
# 4548  Fox News host Tucker Carlson dissects Democrat...
# 4692  'Tucker Carlson Tonight' host Tucker Carlson t...
#
#                                                     url  \
# 4536  /opinion/tucker-carlson-price-us-gas-now-quali...
# 4548  /opinion/tucker-carlson-elizabeth-warren-contr...
# 4692       /media/tucker-carlson-bidens-economic-policy
#
#                 publicationDate          lastPublishedDate  \
# 4536  2022-06-16 05:11:31+00:00  2022-06-16T01:11:31-04:00
# 4548  2022-05-28 03:14:14+00:00  2022-05-27T23:14:14-04:00
# 4692  2021-12-17 06:14:56+00:00  2021-12-17T01:14:56-05:00
#
#                                              category  isBreaking isLive  \
# 4536  {'name': 'OPINION', 'url': '/category/opinion'}       False  False
# 4548  {'name': 'OPINION', 'url': '/category/opinion'}       False  False
# 4692  {'name': 'OPINION', 'url': '/category/opinion'}       False  False
#
#      duration                       authors  \
# 4536      NaN  [{'name': 'Tucker Carlson'}]
# 4548      NaN  [{'name': 'Tucker Carlson'}]
# 4692      NaN  [{'name': 'Tucker Carlson'}]
#
#                                               html_file
# 4536  tucker-carlson-price-us-gas-now-qualifies-cata...
# 4548  tucker-carlson-elizabeth-warren-control-gasoli...
# 4692         tucker-carlson-bidens-economic-policy.html

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#                                                 imageUrl  \
# 0      https://a57.foxnews.com/cf-images.us-east-1.pr...
# 1      https://a57.foxnews.com/cf-images.us-east-1.pr...
# 2      https://a57.foxnews.com/cf-images.us-east-1.pr...
# 3      https://a57.foxnews.com/cf-images.us-east-1.pr...
# 4      https://a57.foxnews.com/cf-images.us-east-1.pr...
# ...                                                  ...
# 54377  https://a57.foxnews.com/cf-images.us-east-1.pr...
# 54378  https://a57.foxnews.com/cf-images.us-east-1.pr...
# 54379  https://a57.foxnews.com/static.foxnews.com/fox...
# 54380  https://a57.foxnews.com/cf-images.us-east-1.pr...
# 54381  https://a57.foxnews.com/cf-images.us-east-1.pr...
#
#                                                    title  \
# 0                  'Fox News Sunday' on October 20, 2024
# 1                'Fox News Sunday' on September 15, 2024
# 2                 'Fox News Sunday' on September 8, 2024
# 3                   'Fox News Sunday' on August 25, 2024
# 4                     'Fox News Sunday' on July 21, 2024
# ...                                                  ...
# 54377  Chicago mother describes struggles of remote l...
# 54378  How polls are reacting to Trump, Biden campaig...
# 54379  Martha MacCallum presses teachers' union head ...
# 54380  Pete Buttigieg slams Trump for taking credit f...
# 54381  How American foreign policy has changed under ...
#
#                                              description  \
# 0      Maryland Gov. Wes Moore weighs in on Harris' p...
# 1      ‘Fox News Sunday’ anchor Shannon Bream welcome...
# 2      This week on 'Fox News Sunday,' host Shannon B...
# 3      This week on ‘Fox News Sunday,’ host Shannon B...
# 4      This week on ‘Fox News Sunday,’ Shannon Bream ...
# ...                                                  ...
# 54377                                                NaN
# 54378                                                NaN
# 54379  "The Story" host Martha MacCallum tangled with...
# 54380                                                NaN
# 54381                                                NaN
#
#                                                      url  \
# 0            /transcript/fox-news-sunday-october-20-2024
# 1          /transcript/fox-news-sunday-september-15-2024
# 2           /transcript/fox-news-sunday-september-8-2024
# 3                  /media/fox-news-sunday-august-25-2024
# 4               /transcript/fox-news-sunday-july-21-2024
# ...                                                  ...
# 54377  /transcript/chicago-mother-describes-struggles...
# 54378  /transcript/how-polls-are-reacting-to-trump-bi...
# 54379  /media/martha-maccallum-randi-weingarten-nyc-s...
# 54380  /transcript/pete-buttigieg-slams-trump-for-tak...
# 54381  /transcript/how-american-foreign-policy-has-ch...
#
#                  publicationDate          lastPublishedDate  \
# 0      2024-10-27 18:14:43+00:00  2024-10-27T14:14:43-04:00
# 1      2024-10-07 13:01:55+00:00  2024-10-07T09:01:55-04:00
# 2      2024-09-10 22:04:22+00:00  2024-09-10T18:04:22-04:00
# 3      2024-08-25 17:40:15+00:00  2024-08-25T13:40:15-04:00
# 4      2024-07-21 17:53:48+00:00  2024-07-21T13:53:48-04:00
# ...                          ...                        ...
# 54377  2021-01-29 15:21:40+00:00  2021-01-29T10:21:40-05:00
# 54378  2020-09-24 16:53:37+00:00  2020-11-25T12:54:46-05:00
# 54379  2020-11-20 01:58:37+00:00  2020-11-19T20:58:37-05:00
# 54380  2020-11-02 15:10:00+00:00  2020-11-14T10:11:20-05:00
# 54381  2020-11-14 14:23:25+00:00  2020-11-14T09:23:25-05:00
#
#                                                 category  isBreaking isLive  \
# 0      {'name': 'TRANSCRIPT', 'url': '/category/shows...       False  False
# 1      {'name': 'TRANSCRIPT', 'url': '/category/shows...       False  False
# 2      {'name': 'TRANSCRIPT', 'url': '/category/shows...       False  False
# 3      {'name': 'TRANSCRIPT', 'url': '/category/shows...       False  False
# 4      {'name': 'TRANSCRIPT', 'url': '/category/shows...       False  False
# ...                                                  ...         ...    ...
# 54377  {'name': 'The Story with Martha MacCallum Tran...       False  False
# 54378  {'name': 'The Story with Martha MacCallum Tran...       False  False
# 54379  {'name': 'Fox News Flash', 'url': '/category/m...       False  False
# 54380  {'name': 'The Story with Martha MacCallum Tran...       False  False
# 54381  {'name': 'The Story with Martha MacCallum Tran...       False  False
#
#       duration                           authors  \
# 0          NaN      [{'name': 'Fox News Staff'}]
# 1          NaN      [{'name': 'Fox News Staff'}]
# 2          NaN      [{'name': 'Fox News Staff'}]
# 3          NaN        [{'name': 'kayla bailey'}]
# 4          NaN      [{'name': 'Fox News Staff'}]
# ...        ...                               ...
# 54377      NaN                                []
# 54378      NaN                                []
# 54379      NaN  [{'name': 'Samuel Chamberlain'}]
# 54380      NaN                                []
# 54381      NaN                                []
#
#                                                html_file
# 0                   fox-news-sunday-october-20-2024.html
# 1                 fox-news-sunday-september-15-2024.html
# 2                  fox-news-sunday-september-8-2024.html
# 3                    fox-news-sunday-august-25-2024.html
# 4                      fox-news-sunday-july-21-2024.html
# ...                                                  ...
# 54377  chicago-mother-describes-struggles-of-remote-l...
# 54378  how-polls-are-reacting-to-trump-biden-campaign...
# 54379  martha-maccallum-randi-weingarten-nyc-school-c...
# 54380  pete-buttigieg-slams-trump-for-taking-credit-f...
# 54381  how-american-foreign-policy-has-changed-under-...
#
# [54382 rows x 12 columns]

# %%
for i, r in df.iterrows():
    fn = 'html/' + r['html_file']
    if os.path.exists(fn):
        continue
    url = r['url']
    headers = {"User-Agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36"}
    try:
        rq = requests.get('https://www.foxnews.com/' + url, headers=headers)
        if rq.status_code == 200:
            with open(fn, 'wb') as f:
                f.write(rq.content)
        else:
            print('ERROR:', rq.status_code)
    except Exception as e:
        print('ERROR:', e)
    time.sleep(0.5)
    if i % 100 == 0:
        print(i, url)
    #break
# Out:
# 0 /transcript/fox-news-sunday-october-20-2024

# %%
df.to_csv('foxnews-transcript.csv.gz', compression='gzip', index=False)
