# %% [markdown]
# ### Get URLs for FNC

# %%
import requests
import time
import logging
import pandas as pd

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    filename='fox_news_transcript_scraper.log',
    filemode='a'
)
logger = logging.getLogger(__name__)

# %%
def fetch_fox_news_category_data(page_size=10, max_retries=3, delay=1):
    """
    Fetch article metadata from Fox News API for the transcript category.
    
    Args:
        page_size: Number of results per page
        max_retries: Maximum number of retry attempts for failed requests
        delay: Time to wait between requests in seconds
        
    Returns:
        List of article metadata items from the transcript category
    """
    category_data = []
    start = 0
    total_fetched = 0
    
    headers = {
        "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36"
    }
    
    logger.info(f"Starting Fox News category API data collection (page size: {page_size})")
    
    while True:
        params = {
            'searchBy': 'categories',
            'values': 'fox-news/transcript',
            'size': page_size,
            'from': start
        }
        
        # Attempt request with retry logic
        for attempt in range(max_retries):
            try:
                response = requests.get(
                    'https://www.foxnews.com/api/article-search',
                    params=params,
                    headers=headers,
                    timeout=10
                )
                response.raise_for_status()  # Raise exception for bad status codes
                break
            except requests.exceptions.RequestException as e:
                logger.error(f"Request failed (attempt {attempt+1}/{max_retries}): {e}")
                if attempt == max_retries - 1:
                    logger.error("Max retries reached. Exiting.")
                    return category_data
                time.sleep(delay * 2)  # Wait longer between retries
        
        # Process successful response
        logger.info(f"Fetched page {start//page_size + 1} (from: {start}, status: {response.status_code})")
        
        try:
            data = response.json()
            if not data:
                logger.info("No more results. Ending pagination.")
                break
                
            count = len(data)
            category_data.extend(data)
            total_fetched += count
            
            logger.info(f"Added {count} items from current page. Total: {total_fetched}")
            
            # Prepare for next page
            start += page_size
            time.sleep(delay)  # Be polite to the server
            
        except ValueError as e:
            logger.error(f"Failed to parse JSON response: {e}")
            break
    
    logger.info(f"Completed category data collection. Total items: {len(category_data)}")
    return category_data

# %%
categories = fetch_fox_news_category_data()

# %%
def process_category_data(categories):
    """
    Process raw category data into a clean DataFrame.
    
    Args:
        categories: List of category data from the Fox News API
        
    Returns:
        DataFrame with processed category information
    """
    # Create initial DataFrame
    cat_df = pd.DataFrame(categories)
    
    # Extract category value and type
    cat_df['cat_value'] = cat_df.category.apply(
        lambda c: 'fox-news' + c['url'].split('/category')[-1] if isinstance(c, dict) and 'url' in c else None
    )
    cat_df['cat_type'] = cat_df.category.apply(
        lambda c: c['name'] if isinstance(c, dict) and 'name' in c else None
    )
    
    # Log some information about the categories
    logger.info(f"Processed {len(cat_df)} items into {cat_df.cat_value.nunique()} unique categories")
    
    return cat_df

# %%
cat_df = process_category_data(results)
cat_df.cat_value.unique()
# Out:
# array(['fox-news/transcript', 'fox-news/shows/fox-news-sunday/transcript',
#        'fox-news/shows/sunday-morning-futures/transcript',
#        'fox-news/shows/media-buzz/transcript',
#        'fox-news/shows/life-liberty-levin/life-liberty-levin-transcript',
#        'fox-news/shows/gutfeld/transcript-gutfeld',
#        'fox-news/shows/ingraham-angle/transcript',
#        'fox-news/shows/hannity/transcript',
#        'fox-news/shows/tucker-carlson-tonight/transcript',
#        'fox-news/shows/special-report/transcript',
#        'fox-news/shows/the-five/transcript',
#        'fox-news/shows/your-world/transcript',
#        'fox-news/shows/fox-news-sunday',
#        'fox-news/shows/cost-of-freedom/transcript',
#        'fox-news/media/fox-news-flash', 'fox-news/shows/gutfeld',
#        'fox-news/shows/on-the-record/transcript',
#        'fox-news/shows/justice-with-judge-jeanine/justice-with-judge-jeanine-transcript',
#        'fox-news/shows/watters-world/watters-world-transcript',
#        'fox-news/shows/hannity', 'fox-news/shows/your-world',
#        'fox-news/shows/tucker-carlson-tonight', 'fox-news/shows/the-five',
#        'fox-news/shows/sunday-morning-futures',
#        'fox-news/shows/watters-world', 'fox-news/shows/special-report',
#        'fox-news/shows/ingraham-angle', 'fox-news/shows/media-buzz',
#        'fox-news/shows/justice-with-judge-jeanine',
#        'fox-news/shows/life-liberty-levin',
#        'fox-news/shows/your-world-cavuto',
#        'fox-news/shows/the-greg-gutfeld-show/the-greg-gutfeld-show-transcript',
#        'fox-news/transcript-gutfeld',
#        'fox-news/shows/the-greg-gutfeld-show',
#        'fox-news/shows/fox-news-night/transcript',
#        'fox-news/shows/the-story/transcript-the-story',
#        'fox-news/shows/the-story/transcript', 'fox-news/shows/the-story',
#        'fox-news/shows/your-world-cavuto/interviews',
#        'fox-news/shows/fox-friends',
#        'fox-news/shows/fox-friends/fox-and-friends-recipes',
#        'fox-news/columns/the-weather-front',
#        'fox-news/shows/the-next-revolution',
#        'fox-news/shows/fox-friends/as-seen-on',
#        'fox-news/columns/fox-friends-blog',
#        'fox-news/shows/journal-editorial-report',
#        'fox-news/shows/journal-editorial-report/transcript',
#        'fox-news/columns/media-buzz',
#        'fox-news/shows/the-five/transcript/gregs-monologue',
#        'fox-news/shows',
#        'fox-news/shows/your-world/transcript/interviews',
#        'fox-news/shows/your-world/transcript/common-sense',
#        'fox-news/shows/your-world-cavuto/common-sense',
#        'fox-news/shows/cost-of-freedom/transcript/cashin-in',
#        'fox-news/shows/cost-of-freedom/transcript/bulls-bears',
#        'fox-news/shows/cost-of-freedom/transcript/cavuto-on-business',
#        'fox-news/shows/cost-of-freedom/transcript/forbes-on-fox',
#        'fox-news/shows/the-fox-news-specialists/transcript',
#        'fox-news/shows/the-fox-news-specialists',
#        'fox-news/shows/oreilly-factor/talking-points',
#        'fox-news/shows/on-the-record/otr-interviews',
#        'fox-news/shows/on-the-record/off-the-record',
#        'fox-news/shows/cost-of-freedom/cashin-in',
#        'fox-news/shows/cost-of-freedom/forbes-on-fox',
#        'fox-news/shows/cost-of-freedom',
#        'fox-news/shows/oreilly-factor/interviews',
#        'fox-news/shows/cost-of-freedom/cavuto-on-business'], dtype=object)

# %%
cat_df[cat_df.cat_type != 'TRANSCRIPT']
# Out:
#                                                imageUrl  \
# 0     https://a57.foxnews.com///static.foxnews.com/s...
# 52    https://a57.foxnews.com/cf-images.us-east-1.pr...
# 54    https://a57.foxnews.com/cf-images.us-east-1.pr...
# 56    https://a57.foxnews.com/cf-images.us-east-1.pr...
# 68    https://a57.foxnews.com/cf-images.us-east-1.pr...
# ...                                                 ...
# 9995  https://a57.foxnews.com///static.foxnews.com/s...
# 9996  https://a57.foxnews.com///static.foxnews.com/s...
# 9997  https://a57.foxnews.com///static.foxnews.com/s...
# 9998  https://a57.foxnews.com///static.foxnews.com/s...
# 9999  https://a57.foxnews.com///static.foxnews.com/s...
#
#                                                   title  \
# 0                       Fox News Sunday Local Air Times
# 52    'Sunday Morning Futures' on Democrats facing a...
# 54    'Life, Liberty & Levin' on what's at stake in ...
# 56    'Gutfeld!' on Paul Pelosi attack reaction, DHS...
# 68      'Gutfeld!' on NYC crime and subway murder rates
# ...                                                 ...
# 9995              Pork Barrel Spending in Pennsylvania?
# 9996  Another Politician Gets Caught With a Resume P...
# 9997  'Special Report' Panel on Mexican President's ...
# 9998                        AllStar Panelist Interviews
# 9999  Mexican President's Opposition to Arizona Law ...
#
#                                             description  \
# 0     Please check back for our updated Fox News Sun...
# 52    Guests: Ted Budd, Robert Cahaly, Mike Lee, Her...
# 54    Guests: Mehmet Oz, Blake Masters, Lee Zeldin, ...
# 56    Guests: Tom Cotton, Emily Compagno, Joe DeVito...
# 68    Guests: Rob Schneider, Michelle Tafoya, Kat Ti...
# ...                                                 ...
# 9995  Show Me the Money Centers named for two Pennsy...
# 9996  Friday Follow-Up In today's Friday Follow-Up, ...
# 9997  PRESIDENT BARACK OBAMA: I think the Arizona la...
# 9998                         BAIER: Let me insert this.
# 9999
#
#                                                     url  \
# 0           /transcript/fox-news-sunday-local-air-times
# 52    /transcript/sunday-morning-futures-democrats-f...
# 54    /transcript/life-liberty-levin-stake-midterm-e...
# 56    /transcript/gutfeld-paul-pelosi-attack-reactio...
# 68    /transcript/gutfeld-on-nyc-crime-and-subway-mu...
# ...                                                 ...
# 9995   /transcript/pork-barrel-spending-in-pennsylvania
# 9996  /transcript/another-politician-gets-caught-wit...
# 9997  /transcript/special-report-panel-on-mexican-pr...
# 9998            /transcript/allstar-panelist-interviews
# 9999  /transcript/mexican-presidents-opposition-to-a...
#
#                 publicationDate          lastPublishedDate  \
# 0     2018-01-16T15:17:00-05:00  2024-11-25T10:16:16-05:00
# 52    2022-11-06T10:00:41-05:00  2022-11-07T10:41:41-05:00
# 54    2022-11-06T20:00:15-05:00  2022-11-07T09:58:43-05:00
# 56    2022-11-01T23:00:58-04:00  2022-11-03T08:37:55-04:00
# 68    2022-10-12T23:00:16-04:00  2022-10-14T15:30:22-04:00
# ...                         ...                        ...
# 9995  2012-04-05T17:40:10-04:00  2017-05-08T16:59:03-04:00
# 9996  2012-04-05T17:40:10-04:00  2017-05-08T16:59:01-04:00
# 9997  2012-04-05T17:40:10-04:00  2017-05-08T16:58:59-04:00
# 9998  2012-04-05T17:40:10-04:00  2017-05-08T16:58:58-04:00
# 9999  2012-04-05T17:40:10-04:00  2017-05-08T16:58:56-04:00
#
#                                                category  isBreaking  isLive  \
# 0     {'name': 'transcript', 'url': '/category/trans...       False   False
# 52    {'name': 'Transcript', 'url': '/category/shows...       False   False
# 54    {'name': 'Life Liberty & Levin Transcript', 'u...       False   False
# 56    {'name': 'Gutfeld Transcript', 'url': '/catego...       False   False
# 68    {'name': 'Gutfeld Transcript', 'url': '/catego...       False   False
# ...                                                 ...         ...     ...
# 9995  {'name': 'SPECIAL REPORT', 'url': '/category/s...       False   False
# 9996  {'name': 'SPECIAL REPORT', 'url': '/category/s...       False   False
# 9997  {'name': 'SPECIAL REPORT', 'url': '/category/s...       False   False
# 9998  {'name': 'SPECIAL REPORT', 'url': '/category/s...       False   False
# 9999  {'name': 'SPECIAL REPORT', 'url': '/category/s...       False   False
#
#      duration authors                                          cat_value  \
# 0                  []                                fox-news/transcript
# 52                 []   fox-news/shows/sunday-morning-futures/transcript
# 54                 []  fox-news/shows/life-liberty-levin/life-liberty...
# 56                 []          fox-news/shows/gutfeld/transcript-gutfeld
# 68                 []          fox-news/shows/gutfeld/transcript-gutfeld
# ...       ...     ...                                                ...
# 9995               []                      fox-news/shows/special-report
# 9996               []                      fox-news/shows/special-report
# 9997               []                      fox-news/shows/special-report
# 9998               []                      fox-news/shows/special-report
# 9999               []                      fox-news/shows/special-report
#
#                              cat_type
# 0                          transcript
# 52                         Transcript
# 54    Life Liberty & Levin Transcript
# 56                 Gutfeld Transcript
# 68                 Gutfeld Transcript
# ...                               ...
# 9995                   SPECIAL REPORT
# 9996                   SPECIAL REPORT
# 9997                   SPECIAL REPORT
# 9998                   SPECIAL REPORT
# 9999                   SPECIAL REPORT
#
# [5068 rows x 13 columns]

# %%
def fetch_fox_news_show_data(cat_df, page_size=30, delay=1, max_retries=1):
    """
    Fetch article data from Fox News API for show tags.
    
    Args:
        cat_df: DataFrame containing category values in a 'cat_value' column
        page_size: Number of results per page
        delay: Time to wait between requests in seconds
        max_retries: Maximum retry attempts for failed requests
        
    Returns:
        List of article data from shows
    """
    all_data = []
    show_count = 0
    
    # Get unique show categories
    show_categories = [val for val in cat_df.cat_value.unique() if 'shows' in val]
    logger.info(f"Found {len(show_categories)} show categories to process")
    
    headers = {
        "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36"
    }
    
    # Process each show category
    for i, values in enumerate(show_categories):
        logger.info(f"Processing category {i+1}/{len(show_categories)}: {values}")
        
        start = 0
        category_items = 0
        
        # Paginate through all results for this category
        while True:
            params = {
                'searchBy': 'tags',
                'values': values,
                'size': page_size,
                'from': start,
                'excludeBy': 'tags',
                'excludeValues': ''
            }
            
            # Try the request with retries
            for attempt in range(max_retries):
                try:
                    response = requests.get(
                        'https://www.foxnews.com/api/article-search', 
                        params=params, 
                        headers=headers,
                        timeout=10
                    )
                    response.raise_for_status()
                    break
                except requests.exceptions.RequestException as e:
                    logger.error(f"Request failed (attempt {attempt+1}/{max_retries}): {e}")
                    if attempt == max_retries - 1:
                        logger.error(f"Max retries reached for {values}. Moving to next category.")
                        break
                    time.sleep(delay * 2)
            
            try:
                results = response.json()
                logger.info(f"Page {start//page_size + 1}: Retrieved {len(results)} items (offset {start})")
                
                # If no results, we've reached the end of this category
                if not results:
                    logger.info(f"No more results for {values}")
                    break
                
                # Add results to our data collection
                all_data.extend(results)
                category_items += len(results)
                
                # Prepare for next page
                start += page_size
                time.sleep(delay)
                
            except ValueError as e:
                logger.error(f"Failed to parse JSON response: {e}")
                break
        
        show_count += 1
        logger.info(f"Completed {values}: {category_items} items")
    
    logger.info(f"Finished processing {show_count} show categories. Total items: {len(all_data)}")
    return all_data

# %%
data = fetch_fox_news_show_data(cat_df)

# %%
df = pd.DataFrame(data)
df.drop_duplicates(subset=['url'], inplace = True)

# %%
df.shape
# Out:
# (87618, 11)

# %%
df['publicationDate'] = pd.to_datetime(df['publicationDate'], utc = True)

# %%
df['publicationDate'].min()
# Out:
# Timestamp('2003-01-02 14:59:23+0000', tz='UTC')

# %%
df['publicationDate'].max()
# Out:
# Timestamp('2025-03-17 20:16:00+0000', tz='UTC')

# %%
df['html_file'] = df.url.apply(lambda c: c.split('/')[-1] + '.html')
df.reset_index(drop=True, inplace=True)
df
# Out:
#                                                 imageUrl  \
# 0      https://a57.foxnews.com/cf-images.us-east-1.pr...
# 1      https://a57.foxnews.com/cf-images.us-east-1.pr...
# 2      https://a57.foxnews.com/cf-images.us-east-1.pr...
# 3      https://a57.foxnews.com/cf-images.us-east-1.pr...
# 4      https://a57.foxnews.com/cf-images.us-east-1.pr...
# ...                                                  ...
# 87613  https://a57.foxnews.com///static.foxnews.com/s...
# 87614  https://a57.foxnews.com/media2.foxnews.com/Bri...
# 87615  https://a57.foxnews.com/media2.foxnews.com/Bri...
# 87616  https://a57.foxnews.com///static.foxnews.com/s...
# 87617  https://a57.foxnews.com/media2.foxnews.com/Bri...
#
#                                                    title  \
# 0                  'Fox News Sunday' on October 20, 2024
# 1                'Fox News Sunday' on September 15, 2024
# 2                 'Fox News Sunday' on September 8, 2024
# 3                   'Fox News Sunday' on August 25, 2024
# 4                     'Fox News Sunday' on July 21, 2024
# ...                                                  ...
# 87613  The transition from President Obama to Preside...
# 87614                Confronting terror around the world
# 87615             Europe under siege from Islamic terror
# 87616  Huckabee blasts Kerry's speech: 'Betrayal' to ...
# 87617          President Obama retaliates against Russia
#
#                                              description  \
# 0      Maryland Gov. Wes Moore weighs in on Harris' p...
# 1      ‘Fox News Sunday’ anchor Shannon Bream welcome...
# 2      This week on 'Fox News Sunday,' host Shannon B...
# 3      This week on ‘Fox News Sunday,’ host Shannon B...
# 4      This week on ‘Fox News Sunday,’ Shannon Bream ...
# ...                                                  ...
# 87613  Karl Rove joins 'The O'Reilly Factor' to discu...
# 87614  Is President Obama's foreign policy legacy a f...
# 87615  'The O'Reilly Factor' analyzes the threat to t...
# 87616  Former Arkansas governor call the secretary of...
# 87617  US announces new slew of sanctions in response...
#
#                                                      url  \
# 0            /transcript/fox-news-sunday-october-20-2024
# 1          /transcript/fox-news-sunday-september-15-2024
# 2           /transcript/fox-news-sunday-september-8-2024
# 3                  /media/fox-news-sunday-august-25-2024
# 4               /transcript/fox-news-sunday-july-21-2024
# ...                                                  ...
# 87613  /transcript/the-transition-from-president-obam...
# 87614    /transcript/confronting-terror-around-the-world
# 87615  /transcript/europe-under-siege-from-islamic-te...
# 87616  /transcript/huckabee-blasts-kerrys-speech-betr...
# 87617  /transcript/president-obama-retaliates-against...
#
#                 publicationDate          lastPublishedDate  \
# 0     2024-10-27 18:14:43+00:00  2024-10-27T14:14:43-04:00
# 1     2024-10-07 13:01:55+00:00  2024-10-07T09:01:55-04:00
# 2     2024-09-10 22:04:22+00:00  2024-09-10T18:04:22-04:00
# 3     2024-08-25 17:40:15+00:00  2024-08-25T13:40:15-04:00
# 4     2024-07-21 17:53:48+00:00  2024-07-21T13:53:48-04:00
# ...                         ...                        ...
# 87613 2016-12-21 13:23:21+00:00  2017-01-23T14:15:22-05:00
# 87614 2016-12-22 13:41:48+00:00  2017-01-23T14:15:00-05:00
# 87615 2016-12-23 13:34:30+00:00  2017-01-23T14:14:41-05:00
# 87616 2016-12-29 13:49:26+00:00  2017-01-23T14:13:28-05:00
# 87617 2016-12-30 13:34:29+00:00  2017-01-23T14:13:03-05:00
#
#                                                 category  isBreaking isLive  \
# 0      {'name': 'TRANSCRIPT', 'url': '/category/shows...       False  False
# 1      {'name': 'TRANSCRIPT', 'url': '/category/shows...       False  False
# 2      {'name': 'TRANSCRIPT', 'url': '/category/shows...       False  False
# 3      {'name': 'TRANSCRIPT', 'url': '/category/shows...       False  False
# 4      {'name': 'TRANSCRIPT', 'url': '/category/shows...       False  False
# ...                                                  ...         ...    ...
# 87613  {'name': 'Interviews', 'url': '/category/shows...       False  False
# 87614  {'name': 'Interviews', 'url': '/category/shows...       False  False
# 87615  {'name': 'Interviews', 'url': '/category/shows...       False  False
# 87616  {'name': 'Interviews', 'url': '/category/shows...       False  False
# 87617  {'name': 'Interviews', 'url': '/category/shows...       False  False
#
#       duration                       authors  \
# 0               [{'name': 'Fox News Staff'}]
# 1               [{'name': 'Fox News Staff'}]
# 2               [{'name': 'Fox News Staff'}]
# 3                 [{'name': 'kayla bailey'}]
# 4               [{'name': 'Fox News Staff'}]
# ...        ...                           ...
# 87613                                     []
# 87614                                     []
# 87615                                     []
# 87616                                     []
# 87617                                     []
#
#                                                html_file
# 0                   fox-news-sunday-october-20-2024.html
# 1                 fox-news-sunday-september-15-2024.html
# 2                  fox-news-sunday-september-8-2024.html
# 3                    fox-news-sunday-august-25-2024.html
# 4                      fox-news-sunday-july-21-2024.html
# ...                                                  ...
# 87613  the-transition-from-president-obama-to-preside...
# 87614           confronting-terror-around-the-world.html
# 87615        europe-under-siege-from-islamic-terror.html
# 87616  huckabee-blasts-kerrys-speech-betrayal-to-isra...
# 87617     president-obama-retaliates-against-russia.html
#
# [87618 rows x 12 columns]

# %%
df.to_csv('../data/foxnews-transcript-urls-2025.csv.gz', index=False, compression='gzip')
