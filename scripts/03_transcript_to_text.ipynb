# %%
import os
import gzip
from bs4 import BeautifulSoup

# %%
# Paths
input_dir = '../data/html/'
output_dir = '../data/text/'

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# List all gzipped HTML files in the directory
html_files = [f for f in os.listdir(input_dir) if f.endswith('.html.gz')]

# Process each file
for i, html_file in enumerate(html_files):
    try:
        # Open and decompress the gzipped file
        with gzip.open(os.path.join(input_dir, html_file), 'rt', encoding='utf-8') as f:
            soup = BeautifulSoup(f.read(), 'html.parser')
        
        texts = []
        elem = soup.find('p', {'class': 'speakable'})
        
        if elem:
            texts.extend(elem.get_text(strip=True, separator='\n').splitlines())
            for elem in elem.next_siblings:
                if hasattr(elem, 'get_text'):  # Check if element has get_text method
                    texts.extend(elem.get_text(strip=True, separator='\n').splitlines())
        
        # Create output filename by removing .gz extension
        txt_file = html_file.replace('.html.gz', '.txt')
        with open(os.path.join(output_dir, txt_file), 'w', encoding='utf-8') as f:
            f.write('\n'.join(texts))
    
    except Exception as e:
        print(e, html_file)
    
    if i % 1000 == 0:
        print(i, html_file)

print(f"Processed {len(html_files)} HTML files")
# Out:
# 0 duck-dynasty-star-phil-robertson-on-aiding-trump-i-pointed-him-to-jesus.html.gz
# 1000 ted-cruz-on-his-campaign-ahead-of-the-iowa-caucuses.html.gz
# 2000 6260618066001.html.gz
# 3000 6368939575112.html.gz
# 4000 buchanan-obama-exposed-as-utterly-naive.html.gz
# 'utf-8' codec can't decode bytes in position 123140-123141: invalid continuation byte alan-dershowitz-on-white-house-dinner-cohen-raid.html.gz
# 5000 sen-rand-paul-budget-deal-brings-back-obama-era-deficits.html.gz
# 6000 6331210464112.html.gz
# 7000 taxes-forcing-businesses-residents-to-move.html.gz
# 8000 bill-oreilly-the-big-republican-debate-and-reaction-to-donald-trump-on-the-factor.html.gz
# 9000 6359616734112.html.gz
# 10000 big-smile-bigger-heart.html.gz
# 11000 6319509061112.html.gz
# 12000 6369575762112.html.gz
# 13000 6366572815112.html.gz
# 14000 sen-lindsey-graham-orlando-is-a-symptom-of-obamas-failing-isis-policy.html.gz
# 15000 archbishop-pelosi-says-walls-are-immoral-so-what-does-she-think-about-israel-and-its-massive-new-wall.html.gz
# 16000 transcript-interior-secretary-gale-norton.html.gz
# 17000 6318874098112.html.gz
# 18000 karl-rove-goes-on-the-record.html.gz
# 19000 6350731635112.html.gz
# 20000 6176075461001.html.gz
# 21000 6140627228001.html.gz
# 22000 sean-hannity-infrastructure-bill-joe-biden-nancy-pelosi.html.gz
# 23000 6366249751112.html.gz
# 24000 how-the-san-bernardino-terrorists-fiance-visa-allowed-her-in-us.html.gz
# 25000 mike-pence-on-travel-restrictions-supreme-court-pick-sen-feinstein-on-challenges-to-trumps-executive-actions.html.gz
# 26000 6331146982112.html.gz
# 27000 is-the-irs-still-harassing-conservative-groups.html.gz
# 28000 tammy-bruce-socialism-american-freedoms.html.gz
# 29000 6306315961112.html.gz
# 30000 6342483794112.html.gz
# 31000 6351998833112.html.gz
# 32000 gorsuch-i-leave-politics-to-the-political-branches-im-here-to-talk-about-the-constitution.html.gz
# 33000 6350161503112.html.gz
# 34000 newt-gingrich-on-president-bushs-news-conference.html.gz
# 35000 interview-sri-lankan-ambassador-and-oxfam-relief-official.html.gz
# 36000 what-would-house-intelligence-look-like-under-schiff.html.gz
# 37000 senate-passes-resolution-to-block-trumps-national-emergency-declaration-to-secure-the-southern-border.html.gz
# 38000 6333524268112.html.gz
# 39000 mollie-hemmingway-we-have-a-violent-crime-crisis-in-this-country.html.gz
# 40000 6313914596112.html.gz
# 41000 cop-under-fire-by-sheriff-david-clarke.html.gz
# 42000 6362366026112.html.gz
# 43000 gutfeld-on-cancel-culture-bidens-afghanistan-mess-american-mental-health.html.gz
# 44000 6142732346001.html.gz
# 45000 6344951862112.html.gz
# 46000 6321432928112.html.gz
# 47000 6327246379112.html.gz
# 48000 6330049361112.html.gz
# 49000 6347277599112.html.gz
# 50000 trump-and-bush-strengths-and-weaknesses.html.gz
# 51000 attorney-in-steinle-case-questions-feds-interest-in-zarate.html.gz
# 52000 transcript-donald-trump-on-housing-crunch.html.gz
# 53000 6324495391112.html.gz
# 54000 mccain-the-self-pity-obama-continues-to-exhibit-is-really-kind-of-sad.html.gz
# 55000 trump-impeachment-ned-ryun-democrats-fools.html.gz
# 56000 6325521904112.html.gz
# 57000 art-collins-chairman-and-ceo-of-meditronic.html.gz
# 58000 6344933197112.html.gz
# 59000 safety-in-the-sky.html.gz
# 60000 lee-zeldin-to-save-new-york-cuomo-must-go.html.gz
# 61000 6251359939001.html.gz
# 62000 6057218495001.html.gz
# 63000 canada-gets-al-jazeera-but-no-fnc.html.gz
# 64000 6328505484112.html.gz
# 65000 tucker-carlson-proof-biden-lackeys-media-lying-about-covid.html.gz
# 66000 lawmaker-calls-for-bank-boycott.html.gz
# 67000 jewish-studies-professor-confronts-student-israel-supporters-guaranteed-spot-hell.html.gz
# 68000 6165853694001.html.gz
# 69000 chris-christies-conservative-problem.html.gz
# 70000 6047143142001.html.gz
# 71000 newt-gingrich-biden-embrace-china-dictatorship.html.gz
# 72000 irs-getting-grilled-on-capitol-hill.html.gz
# 73000 6347282400112.html.gz
# 'utf-8' codec can't decode byte 0x97 in position 352386: invalid start byte watters-world-on-the-fight-against-critical-race-theory.html.gz
# 74000 grapevine-pundit-has-a-problem-with-darth-vaders-race.html.gz
# 75000 6326151910112.html.gz
# 76000 california-parents-sitout-kids-school-vaccine-mandates.html.gz
# 77000 6316163838112.html.gz
# 78000 nancy-pelosi-on-negotiations-over-small-business-relief-program-criticism-of-trumps-plan-to-reopen-nation.html.gz
# 79000 geraldo-reacts-to-imus-firing.html.gz
# 80000 greta-farewell-and-good-luck-to-my-assistant-jenn-holton.html.gz
# 81000 war-between-the-free-media-the-elite-media.html.gz
# 82000 the-failure-to-confront-evil.html.gz
# 83000 6317228511112.html.gz
# 84000 6353469632112.html.gz
# 85000 short-questions-dana-perino-tom-shillue.html.gz
# 86000 6367969855112.html.gz
# 87000 6302649262001.html.gz
# Processed 87403 HTML files

# %%
import tarfile

# Specify the folder to compress and the output filename
folder_to_compress = "../data/text/"  # Replace with your folder path
output_filename = "../data/fnc_transcripts_text_2025.tar.gz"          # Name of the output archive

def create_tarball(source_dir, output_filename):
    with tarfile.open(output_filename, "w:gz") as tar:
        # Add the directory to the archive
        tar.add(source_dir, arcname=os.path.basename(source_dir))
    
    print(f"Created archive: {output_filename}")
    print(f"Archive size: {os.path.getsize(output_filename) / (1024*1024):.2f} MB")

# Run the function
create_tarball(folder_to_compress, output_filename)
# Out:
# Created archive: ../data/fnc_transcripts_text_2025.tar.gz
# Archive size: 198.04 MB

# %%
urls = pd.read_csv("../data/foxnews-transcript-urls-2025.csv")

# %%
urls.head()
# Out:
#                                             imageUrl  \
# 0  https://a57.foxnews.com/cf-images.us-east-1.pr...
# 1  https://a57.foxnews.com/cf-images.us-east-1.pr...
# 2  https://a57.foxnews.com/cf-images.us-east-1.pr...
# 3  https://a57.foxnews.com/cf-images.us-east-1.pr...
# 4  https://a57.foxnews.com/cf-images.us-east-1.pr...
#
#                                      title  \
# 0    'Fox News Sunday' on October 20, 2024
# 1  'Fox News Sunday' on September 15, 2024
# 2   'Fox News Sunday' on September 8, 2024
# 3     'Fox News Sunday' on August 25, 2024
# 4       'Fox News Sunday' on July 21, 2024
#
#                                          description  \
# 0  Maryland Gov. Wes Moore weighs in on Harris' p...
# 1  ‘Fox News Sunday’ anchor Shannon Bream welcome...
# 2  This week on 'Fox News Sunday,' host Shannon B...
# 3  This week on ‘Fox News Sunday,’ host Shannon B...
# 4  This week on ‘Fox News Sunday,’ Shannon Bream ...
#
#                                              url            publicationDate  \
# 0    /transcript/fox-news-sunday-october-20-2024  2024-10-27 18:14:43+00:00
# 1  /transcript/fox-news-sunday-september-15-2024  2024-10-07 13:01:55+00:00
# 2   /transcript/fox-news-sunday-september-8-2024  2024-09-10 22:04:22+00:00
# 3          /media/fox-news-sunday-august-25-2024  2024-08-25 17:40:15+00:00
# 4       /transcript/fox-news-sunday-july-21-2024  2024-07-21 17:53:48+00:00
#
#            lastPublishedDate  \
# 0  2024-10-27T14:14:43-04:00
# 1  2024-10-07T09:01:55-04:00
# 2  2024-09-10T18:04:22-04:00
# 3  2024-08-25T13:40:15-04:00
# 4  2024-07-21T13:53:48-04:00
#
#                                             category  isBreaking isLive  \
# 0  {'name': 'TRANSCRIPT', 'url': '/category/shows...       False  False
# 1  {'name': 'TRANSCRIPT', 'url': '/category/shows...       False  False
# 2  {'name': 'TRANSCRIPT', 'url': '/category/shows...       False  False
# 3  {'name': 'TRANSCRIPT', 'url': '/category/shows...       False  False
# 4  {'name': 'TRANSCRIPT', 'url': '/category/shows...       False  False
#
#   duration                       authors
# 0      NaN  [{'name': 'Fox News Staff'}]
# 1      NaN  [{'name': 'Fox News Staff'}]
# 2      NaN  [{'name': 'Fox News Staff'}]
# 3      NaN    [{'name': 'kayla bailey'}]
# 4      NaN  [{'name': 'Fox News Staff'}]

# %%
urls['publicationDate'] = pd.to_datetime(urls['publicationDate'])
urls['year'] = urls['publicationDate'].dt.year
yearly_counts = urls.groupby('year').size().reset_index(name='count')

markdown_table = "| Year | Count |\n| --- | --- |\n"
for _, row in yearly_counts.iterrows():
    markdown_table += f"| {row['year']} | {row['count']} |\n"

# %%
markdown_table
# Out:
# '| Year | Count |\n| --- | --- |\n| 2003 | 450 |\n| 2004 | 365 |\n| 2005 | 431 |\n| 2006 | 411 |\n| 2007 | 304 |\n| 2008 | 418 |\n| 2009 | 425 |\n| 2010 | 314 |\n| 2011 | 523 |\n| 2012 | 1019 |\n| 2013 | 777 |\n| 2014 | 866 |\n| 2015 | 890 |\n| 2016 | 821 |\n| 2017 | 1259 |\n| 2018 | 1752 |\n| 2019 | 5865 |\n| 2020 | 5995 |\n| 2021 | 5400 |\n| 2022 | 6782 |\n| 2023 | 9585 |\n| 2024 | 8256 |\n| 2025 | 1474 |\n'
